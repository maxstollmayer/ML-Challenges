# %%
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sn
# %matplotlib inline

# %% [markdown]
# Two files will be supplied to you via Moodle. A test and training set 'data_train_db.csv' and 'data_test_db.csv'.
# They were taken by observing a mystery machine. The first entry 'Running' is 1 if the machine worked. It is 0 if it failed to work.
# In the test set, the labels, are set to 2. You should predict them.
#
#
# Let us look at out data first:

# %%
data_train_db = pd.read_csv('data_train_db.csv')
data_test_db = pd.read_csv('data_test_db.csv')
data_train_db.head()
# Out:
#    Running  Blue Switch On  Battery level  Humidity  Magnetic field  \
# 0      1.0             1.0       0.472619  0.681050        0.884694
# 1      1.0             1.0       0.688965  0.988019        0.716011
# 2      1.0             1.0       0.788401  0.752765        0.801923
# 3      0.0             1.0       0.739938  0.517953        0.431417
# 4      1.0             1.0       0.525988  0.532473        0.920489
#
#    Controller beige  Controller bisque  Controller black  \
# 0          0.888819           0.949818          0.656389
# 1          0.567877           0.463229          0.424654
# 2          0.847497           0.743526          0.931443
# 3          0.894524           0.752744          0.907213
# 4          0.898508           0.707683          0.743687
#
#    Controller blanchedalmond  Time since restart  ...  Waste level right tank  \
# 0                   0.788241            8.031743  ...                0.921479
# 1                   0.931444            5.165232  ...                0.562749
# 2                   0.768209            9.436875  ...                0.881300
# 3                   0.871284            3.651928  ...                0.926289
# 4                   0.726896            6.582867  ...                0.434560
#
#    Waste level left tank  Helium reservoir  alpha-radiation  \
# 0               0.759088          0.742684         0.958868
# 1               0.932735          0.684856         0.914809
# 2               0.417064          0.468547         0.796907
# 3               0.464410          0.958722         0.520464
# 4               0.746746          0.466800         0.942878
#
#    Active motion supression  Blade density  Blade rotation  \
# 0                  0.546771       0.736409        0.471570
# 1                  0.972892       0.450422        0.471924
# 2                  0.986931       0.847634        0.728937
# 3                  0.999992       0.838839        0.506759
# 4                  0.781556       0.850591        0.592054
#
#    Controller mintcream  Controller mistyrose  Controller moccasin
# 0              0.986777              0.600762             0.412784
# 1              0.453124              0.976749             0.597788
# 2              0.895689              0.970808             0.752744
# 3              0.662043              0.659098             0.953559
# 4              0.549517              0.574893             0.472128
#
# [5 rows x 100 columns]

# %% [markdown]
# Lets look at some more properties of the data:

# %%
data_train_db.describe()
# Out:
#            Running  Blue Switch On  Battery level     Humidity  \
# count  2000.000000     2000.000000    2000.000000  2000.000000
# mean      0.311500        0.824642       0.732381     0.670628
# std       0.463222        0.712109       2.280995     1.275480
# min       0.000000      -22.759721     -38.055832   -40.878137
# 25%       0.000000        1.000000       0.549734     0.542930
# 50%       0.000000        1.000000       0.698123     0.696592
# 75%       1.000000        1.000000       0.849506     0.844798
# max       1.000000       12.440382      77.644402    26.567088
#
#        Magnetic field  Controller beige  Controller bisque  Controller black  \
# count     2000.000000       2000.000000        2000.000000       2000.000000
# mean         0.658450          0.732612           0.724687          0.710984
# std          1.410498          0.932445           1.290294          0.546794
# min        -50.779683          0.400771         -18.190763         -9.042823
# 25%          0.551090          0.555667           0.549273          0.560411
# 50%          0.706609          0.698498           0.690762          0.704883
# 75%          0.852589          0.850872           0.851927          0.851071
# max          2.181685         37.371873          49.427813         15.914141
#
#        Controller blanchedalmond  Time since restart  ...  \
# count                2000.000000         2000.000000  ...
# mean                    0.650322            5.055976  ...
# std                     1.896914            2.913774  ...
# min                   -58.024379          -16.002695  ...
# 25%                     0.545552            2.604643  ...
# 50%                     0.686504            5.259820  ...
# 75%                     0.847418            7.473587  ...
# max                    41.007128           15.007247  ...
#
#        Waste level right tank  Waste level left tank  Helium reservoir  \
# count             2000.000000            2000.000000       2000.000000
# mean                 0.727262               0.696894          0.750866
# std                  1.486712               1.137658          1.026275
# min                -10.323221             -37.190701          0.400418
# 25%                  0.547473               0.544204          0.557663
# 50%                  0.693606               0.690501          0.710034
# 75%                  0.849670               0.848295          0.852120
# max                 64.521486              24.881777         27.812705
#
#        alpha-radiation  Active motion supression  Blade density  \
# count      2000.000000               2000.000000    2000.000000
# mean          0.734427                  0.709659       0.718897
# std           1.003642                  1.767397       0.881690
# min          -2.200456                -35.383528     -14.777491
# 25%           0.542622                  0.558572       0.553339
# 50%           0.703849                  0.700996       0.710563
# 75%           0.849593                  0.850362       0.851460
# max          37.703893                 63.615672      21.558254
#
#        Blade rotation  Controller mintcream  Controller mistyrose  \
# count     2000.000000           2000.000000           2000.000000
# mean         0.657022              0.713340              0.737840
# std          2.225722              1.950032              1.714560
# min        -78.787165            -59.091836            -38.224559
# 25%          0.554327              0.548380              0.551331
# 50%          0.704225              0.703970              0.702484
# 75%          0.862595              0.859953              0.851893
# max         33.059216             45.192744             50.991319
#
#        Controller moccasin
# count          2000.000000
# mean              0.658718
# std               1.515071
# min             -63.751219
# 25%               0.548054
# 50%               0.706985
# 75%               0.847668
# max               3.883941
#
# [8 rows x 100 columns]

# %% [markdown]
# How is the distribution of the labels?

# %%
data_train = data_train_db.values

labels = 'Runs', 'Does not run'
sizes = [np.sum(data_train[:,0]), np.sum(1-data_train[:,0])]

fig1, ax1 = plt.subplots()
ax1.pie(sizes, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=90)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.show()

# %% [markdown]
# Lets look at some standard statistics of the data:

# %%
fig = plt.figure(figsize = (14, 4))

plt.subplot(1,2,1)
plt.hist(data_train[data_train[:,0] == 1,1:].std(1))
plt.title('Distribution of standard deviation--- not running')
plt.subplot(1,2,2)
plt.hist(data_train[data_train[:,0] == 0,1:].std(1))
plt.title('Distribution of standard deviation--- not running')

fig = plt.figure(figsize = (14, 4))

plt.subplot(1,2,1)
plt.hist(np.sum(data_train[data_train[:,0]==1,1:], 1)/100)
plt.title('Distribution of means--- running')
plt.subplot(1,2,2)
plt.hist(np.sum(data_train[data_train[:,0]==0,1:], 1)/100)
plt.title('Distribution of means--- not running')

fig = plt.figure(figsize = (14, 4))

plt.subplot(1,2,1)
plt.hist(np.amax(data_train[data_train[:,0] == 1,1:], axis = 1))
plt.title('Distribution of max value--- running')
plt.subplot(1,2,2)
plt.hist(np.amax(data_train[data_train[:,0] == 0,1:], axis = 1))
plt.title('Distribution of max value--- not running')

fig = plt.figure(figsize = (14, 4))

plt.subplot(1,2,1)
plt.hist(np.amin(data_train[data_train[:,0] == 1,1:], axis = 1))
plt.title('Distribution of min value--- running')
plt.subplot(1,2,2)
plt.hist(np.amin(data_train[data_train[:,0] == 0,1:], axis = 1))
plt.title('Distribution of min value--- not running')
# Out:
# Text(0.5, 1.0, 'Distribution of min value--- not running')

# %% [markdown]
# The distribution of the min values is a bit worrying. Since some very few entries have very high standard deviation, some very few and possibly the same values have very low negative values, but almost all other entries have only positive values. This may be a problem in the data set. We decide that these entries are outliers and drop these entries from the data base.

# %%
# It seems like there are some data points which have much higher standard deviation than most. Lets just remove those.


def clean_dataset(data):
    to_drop= []
    for k in range(data.shape[0]):
        if data[k,:].std()>15:
            to_drop.append(k)   
    return np.delete(data, to_drop, axis = 0)

# %% [markdown]
# Let us apply the cleaning and look at the data set again

# %%
data_train = clean_dataset(data_train)

fig = plt.figure(figsize = (14, 4))

plt.subplot(1,2,1)
plt.hist(data_train[data_train[:,0] == 1,1:].std(1))
plt.title('Distribution of standard deviation--- not running')
plt.subplot(1,2,2)
plt.hist(data_train[data_train[:,0] == 0,1:].std(1))
plt.title('Distribution of standard deviation--- not running')

fig = plt.figure(figsize = (14, 4))

plt.subplot(1,2,1)
plt.hist(np.amin(data_train[data_train[:,0] == 1,1:], axis = 1))
plt.title('Distribution of min value--- running')
plt.subplot(1,2,2)
plt.hist(np.amin(data_train[data_train[:,0] == 0,1:], axis = 1))
plt.title('Distribution of min value--- not running')
# Out:
# Text(0.5, 1.0, 'Distribution of min value--- not running')

# %% [markdown]
# This looks much better.
#
# Now we start understanding our data set a bit more in detaill. Let us try to get a feeling of the dependencies between the columns.

# %%
data_train_db.corr()
# Out:
#                        Running  Blue Switch On  Battery level  Humidity  \
# Running               1.000000        0.165678      -0.010490  0.008206
# Blue Switch On        0.165678        1.000000       0.412399  0.307784
# Battery level        -0.010490        0.412399       1.000000 -0.434481
# Humidity              0.008206        0.307784      -0.434481  1.000000
# Magnetic field        0.016983        0.719586       0.284702  0.405029
# ...                        ...             ...            ...       ...
# Blade density        -0.015352        0.398472       0.022940  0.541918
# Blade rotation        0.014215        0.055204      -0.327950  0.097195
# Controller mintcream -0.003694        0.774943       0.614790  0.233201
# Controller mistyrose  0.025988       -0.557551       0.022663 -0.757314
# Controller moccasin  -0.025717        0.117672       0.152045  0.318898
#
#                       Magnetic field  Controller beige  Controller bisque  \
# Running                     0.016983         -0.019722          -0.016225
# Blue Switch On              0.719586         -0.033023           0.480797
# Battery level               0.284702         -0.104328           0.569988
# Humidity                    0.405029         -0.021046          -0.062676
# Magnetic field              1.000000         -0.506311           0.078928
# ...                              ...               ...                ...
# Blade density               0.052560          0.687922           0.643872
# Blade rotation              0.450071         -0.515774          -0.673308
# Controller mintcream        0.698135          0.044125           0.549155
# Controller mistyrose       -0.779847          0.338765           0.109041
# Controller moccasin         0.504974         -0.860270          -0.466830
#
#                       Controller black  Controller blanchedalmond  \
# Running                      -0.011492                   0.015929
# Blue Switch On               -0.558371                   0.117452
# Battery level                -0.344456                  -0.643055
# Humidity                     -0.601855                   0.613828
# Magnetic field               -0.664258                   0.099356
# ...                                ...                        ...
# Blade density                -0.346306                   0.375855
# Blade rotation                0.034138                  -0.069962
# Controller mintcream         -0.635048                  -0.181918
# Controller mistyrose          0.770118                  -0.141762
# Controller moccasin          -0.647338                  -0.265558
#
#                       Time since restart  ...  Waste level right tank  \
# Running                         0.033208  ...               -0.010974
# Blue Switch On                  0.022209  ...               -0.665157
# Battery level                  -0.131296  ...               -0.027986
# Humidity                        0.017871  ...               -0.292348
# Magnetic field                  0.052415  ...               -0.701495
# ...                                  ...  ...                     ...
# Blade density                  -0.050143  ...               -0.313025
# Blade rotation                  0.138416  ...               -0.327453
# Controller mintcream           -0.044189  ...               -0.578847
# Controller mistyrose           -0.008801  ...                0.449133
# Controller moccasin            -0.067322  ...                0.211336
#
#                       Waste level left tank  Helium reservoir  \
# Running                            0.003621         -0.034627
# Blue Switch On                     0.755084         -0.346429
# Battery level                      0.567165          0.243991
# Humidity                           0.092500         -0.528233
# Magnetic field                     0.704351         -0.783452
# ...                                     ...               ...
# Blade density                      0.384829          0.236253
# Blade rotation                     0.216854         -0.661616
# Controller mintcream               0.947205         -0.179212
# Controller mistyrose              -0.550975          0.699200
# Controller moccasin               -0.009810         -0.623121
#
#                       alpha-radiation  Active motion supression  \
# Running                     -0.022128                 -0.002572
# Blue Switch On              -0.346293                 -0.748355
# Battery level               -0.132634                 -0.519186
# Humidity                    -0.031658                 -0.018538
# Magnetic field              -0.487886                 -0.616350
# ...                               ...                       ...
# Blade density                0.203052                 -0.392370
# Blade rotation               0.063830                  0.072227
# Controller mintcream        -0.042973                 -0.759843
# Controller mistyrose        -0.008841                  0.252746
# Controller moccasin         -0.124575                  0.248496
#
#                       Blade density  Blade rotation  Controller mintcream  \
# Running                   -0.015352        0.014215             -0.003694
# Blue Switch On             0.398472        0.055204              0.774943
# Battery level              0.022940       -0.327950              0.614790
# Humidity                   0.541918        0.097195              0.233201
# Magnetic field             0.052560        0.450071              0.698135
# ...                             ...             ...                   ...
# Blade density              1.000000       -0.422271              0.509281
# Blade rotation            -0.422271        1.000000              0.064192
# Controller mintcream       0.509281        0.064192              1.000000
# Controller mistyrose      -0.335341       -0.458635             -0.637136
# Controller moccasin       -0.358705        0.290417              0.112301
#
#                       Controller mistyrose  Controller moccasin
# Running                           0.025988            -0.025717
# Blue Switch On                   -0.557551             0.117672
# Battery level                     0.022663             0.152045
# Humidity                         -0.757314             0.318898
# Magnetic field                   -0.779847             0.504974
# ...                                    ...                  ...
# Blade density                    -0.335341            -0.358705
# Blade rotation                   -0.458635             0.290417
# Controller mintcream             -0.637136             0.112301
# Controller mistyrose              1.000000            -0.549950
# Controller moccasin              -0.549950             1.000000
#
# [100 rows x 100 columns]

# %%
corrMatrix = data_train_db.corr()
plt.figure(figsize = (12,12))
sn.heatmap(corrMatrix, annot=False)
plt.show()

plt.figure(figsize = (12,6))
plt.plot(np.arange(1, 100), corrMatrix['Running'][1:100])
plt.title('Correlation with Running')
plt.show()

# %% [markdown]
# The first row of the data set (after the row 'Running' itself), seems to be suspiciously important. Lets look at it in isolation.

# %%
plt.hist(data_train[:,1])
plt.title(data_train_db.columns[1])
# Out:
# Text(0.5, 1.0, 'Blue Switch On')

# %% [markdown]
# We see that 'Blue Switch On' only takes two values (On and Off). Let us look in detail, what the effect of this switch is on whether the mechanism runs or not.

# %%
runs_switchon = np.count_nonzero((data_train[:,0]==1)*(data_train[:,1]==1))
runs_switchoff = np.count_nonzero((data_train[:,0]==1)*(data_train[:,1]==0))
runsnot_switchon = np.count_nonzero((data_train[:,0]==0)*(data_train[:,1]==1))
runsnot_switchoff = np.count_nonzero((data_train[:,0]==0)*(data_train[:,1]==0))
conf_matrix = [[runs_switchon, runs_switchoff], [runsnot_switchon, runsnot_switchoff]]

sn.set(color_codes=True)
plt.figure(1, figsize=(9, 6))

plt.title("Confusion Matrix")

sn.set(font_scale=1.4)
ax = sn.heatmap(conf_matrix, annot=True, cmap="YlGnBu", fmt='2')

ax.set_yticklabels(['runs', 'does not run'])
ax.set_xticklabels(['Blue Switch On', 'Blue Switch Off'])
# Out:
# [Text(0.5, 0, 'Blue Switch On'), Text(1.5, 0, 'Blue Switch Off')]

# %% [markdown]
# Now this is fantastic. If the Blue Switch is off, then the mechanism never works.
#
# Next, we would like to extract additional important parameters of the machine. We rank the columns according to their correlation with 'Running':

# %%
S = np.argsort(np.array(corrMatrix['Running']))[::-1]
print(S)
# Out:
# [ 0  1 72 70 74 68  9 39 11 98 40 82 73  4 76 17 83  8 31 66 28 96 41 89
#  58 21 33 42 26 49 27 35 65  3 15 80 12 25 36 19 23 71 32 91 43 59 24 22
#  37 87 94 46 97 81 10 67 16 29 64 85 55 18 44 61 60 52 48 50 56 54 45  2
#  88 90 53 77  7 63 79 34 14 95 84  6 69 38 62 47 30 75  5 93 20 86 99 51
#  13 78 57 92]

# %% [markdown]
# We saw that the first entry is always 1 if the method is working.
# Also from the ranking above, we expect that large values in coordinates 72 and 98 seem to indicate that the algorithm works.
#
# Let us describe a Hypothesis set that thakes this observation into account, by defining a classifier below. The hypothesis set is characterised by a threshholding value 'thresh'.

# %%
def myclassifier(data, thresh):
    if data[1] == 0:
        return 0 # If the blue switch is off, then we know that the mechanism wont work.
    if data[72] + data[98] > thresh:
        return 1
    return 0

# %% [markdown]
# Next we find the value thresh, that yields the best classification on the test set:

# %%
best_thresh = 0
best_err = data_train.shape[0]

for tr in range(100):
    thresh = tr/20
    err = 0
    for t in range(data_train.shape[0]):
        err = err + (myclassifier(data_train[t, :], thresh) != data_train[t, 0])
    if err < best_err:
        best_err = err
        best_thresh = thresh

print('Test accuracy:' + str(1-best_err/data_train.shape[0]))
# Out:
# Test accuracy:0.7799498746867168

# %% [markdown]
# The test accuracy above is quite terrible. It is your task to perform better than this.

# %%
predicted_labels = np.zeros(data_test_db.shape[0])
data_test = data_test_db.values

for k in range(data_test_db.shape[0]):
    predicted_labels[k] = myclassifier(data_test[k, :], best_thresh)
    
np.savetxt('PhilippPetersens_prediction.csv', predicted_labels, delimiter=',')

# %% [markdown]
# send your result via email to philipp.petersen@univie.ac.at.
# your email should also include
#
# - the names of all people who worked on your code,
# - their student identification number,
# - a name for your team,
# - the code used.
# - a short (3-4 sentence) explanation of the main idea.
#
# The winners of the challenge receive extra points, a certificate, and may be asked to present their idea during one of the lectures.
